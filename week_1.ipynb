# %%
# Out:
#   File "/tmp/ipykernel_1834/1583703148.py", line 1
#     input and output formated functions
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# input and output formated functions

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("Hello World!")
print("I am learning Python.")
print("It is awesome!")
# Out:
# Hello World!
# I am learning Python.
# It is awesome!

# %%
name = input("Enter your name:")
print(name)
# Out:
# Enter your name:akshara
# akshara

# %%
name = "akshara"
age = 20

print(name, age)
# Out:
# akshara 20

# %%
name = "akshara"
marks = 95

print(f"student name:{name}")
print(f"marks:{marks}")
# Out:
# student name:akshara
# marks:95

# %%
name = "akshara"
marks = 95

print("Student Name: {}".format(name))
print("Marks: {}".format(marks))
# Out:
# Student Name: akshara
# Marks: 95

# %%
name = "akshara"
marks = 95

print("Student Name: %s" % name)
print("Marks: %d" % marks)
# Out:
# Student Name: akshara
# Marks: 95

# %%
print("welcome to python")
# Out:
# welcome to python

# %%
print(25)
print(50)
# Out:
# 25
# 50

# %%
name = "akshara"
print(name)
# Out:
# akshara

# %%
a=15
b=10
print()

# %%
a=20
b=4
print()
print()

# %%
a=20
b=3
print()

# %%
name="akshara"
age=19

# %%
name="akshara"
age=19

# %%
name="akshara"

# %%
city="hyderabad"

# %%
x=2
print()

# %%
value = 15.522222
print(type(value))
# Out:
# <class 'float'>

# %%
print("Python","Programming","Language")
# Out:
# Python Programming Language

# %%
a = 10
b = 20
print("Sum =", a + b)
# Out:
# Sum = 30

# %%
name = "akshara"
print(name * 3)
# Out:
# aksharaaksharaakshara

# %%
name = "akshara"
cgpa = 8.75

# %% [markdown]
# Q1. Write the output.
# print("Welcome to Python")
# Output: _____________________welcome to python___________
#
# Q2. Write the output.
# print(25)
# print(50)
# Output: ___25
# 50_____________________________
#
# Q3. Write the output.
# name = "rahul"
# print(name)
# Output: ______________rahul__________________
#
# Q4. Write the output.
# a = 15
# b = 10
# print()
# Output: ____________
# ____________________
#
# Q5. Write the output.
# a = 20
# b = 4
# print()
# print()
# Output: _____
#
# ___________________________
#
# Q6. Write the output.
# a = 20
# b = 3
#
# print ()
# Output: ____
# ____________________________
#
# Q7. Write the output.
# name = "Anjali"
# age = 19
#
# Output: ________________________________
#
# Q8. Write the output with f string
# name = &quot;Priya&quot;
#
# Output: ________________________________
#
# Q9. Write the output with formar
# city = &quot;Hyderabad&quot;
#
# Output: ________________________________
#
# Q10. Write the output % formar
# name = &quot;Kiran&quot;
#
# Output: ________________________________
#
# Q11. Write the output.
# a = 5
# b = 4
#
# Output: ________________________________
#
# Q12. Write the output.
# x = 2
# print()
# Output: ________________________________
#
# Q13. Write the output.
# num = 25
# print()
# Output: ________________________________
#
# Q14. Write the float output with with 2 precision values
# value = 15.522222
# print(type(value))
# Output: _______float_________________________
#
# Q15. Write the output with f string
# name = &quot;Asha&quot;
# marks = 92
#
# Output: ________________________________
#
# Q16. Write the output.
# print(&quot;Python&quot;, &quot;Programming&quot;, &quot;Language&quot;)
# Output: ________________________________
#
# Q17. Write the output.
# a = 10
# b = 20
# print(&quot;Sum =&quot;, a + b)
# Output: ____________sum=30____________________
#
# Q18. Write the output.
# name = &quot;Rahul&quot;
# print(name * 3)
# Output: ________________rahulrahulrahul________________
#
# Q19. Write the output.
# age = input(&quot;Enter Age: &quot;)
#
# Output: ________________________________
#
# Q20. Write the output with fstring
# x = 10
# y = 20
#
# Output: ________________________________
#
# Q21. Write the output.
# name = &quot;Amit&quot;
# cgpa = 8.75
#
# Output: ________________________________

# %% [markdown]
# functions

# %%
def greet():
    print("Hello! Welcome to Python Functions.")

# Calling the function
greet()
# Out:
# Hello! Welcome to Python Functions.

# %%
def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Alice")
greet_user("Bob")
# Out:
# Hello, Alice!
# Hello, Bob!

# %%
def greet_user(name="Guest"):
    print(f"Welcome, {name}!")

greet_user()         # Uses default
greet_user("Ravi")   # Overrides default
# Out:
# Welcome, Guest!
# Welcome, Ravi!

# %%
def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("Alice", "bob", "Charlie")
# Out:
# Names passed: ('Alice', 'bob', 'Charlie')
# Hello Alice
# Hello bob
# Hello Charlie

# %%
def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")

print_info(name="Alice", age=25, city="Delhi")
# Out:
# User Info:
# name = Alice
# age = 25
# city = Delhi

# %%
def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="Ravi", city="Mumbai")
# Out:
# Args: (1, 2, 3)
# Kwargs: {'name': 'Ravi', 'city': 'Mumbai'}

# %%
def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("square of 4:", square(4))
# Out:
# Square of 4: 16
